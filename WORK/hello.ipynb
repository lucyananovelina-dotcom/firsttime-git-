# %%
suatu_variable = "kosong adalah isi"

suatu_variable
# Out:
# 'kosong adalah isi'

# %% [markdown]
# # heading 1  /
# ## heading 2 /
# ### heading 3 /
# #### heading 4 /
#
#
# >ini blockquote
#
# _iniBOLD_
#
# **bold**

# %%
print ("halo dunia")
# Out:
# halo dunia
